# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulsidibe/Cousera-test/blob/master/salaryYearExperience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##In this code we are going develop a linear regression simple AI using python sklearn library.
##The AI will a celsius degree as input and oupt the corresponding fahrenheit


##let begin by trying to first understand out dataset using pandas
import pandas as pd

data = pd.read_csv('Salary_dataset.csv')

data
# Out:
#     YearsExperience  Salary
# 0               1.2   39344
# 1               1.4   46206
# 2               1.6   37732
# 3               2.1   43526
# 4               2.3   39892
# 5               3.0   56643
# 6               3.1   60151
# 7               3.3   54446
# 8               3.3   64446
# 9               3.8   57190
# 10              4.0   63219
# 11              4.1   55795
# 12              4.1   56958
# 13              4.2   57082
# 14              4.6   61112
# 15              5.0   67939
# 16              5.2   66030
# 17              5.4   83089
# 18              6.0   81364
# 19              6.1   93941
# 20              6.9   91739
# 21              7.2   98274
# 22              8.0  101303
# 23              8.3  113813
# 24              8.8  109432
# 25              9.1  105583
# 26              9.6  116970
# 27              9.7  112636
# 28             10.4  122392
# 29             10.6  121873

# %%
##let us seaborn library's scatterplot function to see how linear is our dataset

import seaborn as sb

sb.scatterplot(x = 'YearsExperience', y='Salary', data=data, hue='Salary', palette='coolwarm')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
##let prepare our data set for using using the characterize and reshape the data
##using the numpy values and reshape functions

##store Experience and Salary values in to an array name x and y

x = data['YearsExperience']
y = data['Salary']

##print the x values (you get the memo)
y
# Out:
# 0      39344
# 1      46206
# 2      37732
# 3      43526
# 4      39892
# 5      56643
# 6      60151
# 7      54446
# 8      64446
# 9      57190
# 10     63219
# 11     55795
# 12     56958
# 13     57082
# 14     61112
# 15     67939
# 16     66030
# 17     83089
# 18     81364
# 19     93941
# 20     91739
# 21     98274
# 22    101303
# 23    113813
# 24    109432
# 25    105583
# 26    116970
# 27    112636
# 28    122392
# 29    121873
# Name: Salary, dtype: int64

# %%
##value function to convert the x values in an array
##and the reshape funtion to return the data into an array of arrays
xProcessed = x.values.reshape(-1,1)
yProcessed = y.values.reshape(-1,1)

yProcessed
# Out:
# array([[ 39344],
#        [ 46206],
#        [ 37732],
#        [ 43526],
#        [ 39892],
#        [ 56643],
#        [ 60151],
#        [ 54446],
#        [ 64446],
#        [ 57190],
#        [ 63219],
#        [ 55795],
#        [ 56958],
#        [ 57082],
#        [ 61112],
#        [ 67939],
#        [ 66030],
#        [ 83089],
#        [ 81364],
#        [ 93941],
#        [ 91739],
#        [ 98274],
#        [101303],
#        [113813],
#        [109432],
#        [105583],
#        [116970],
#        [112636],
#        [122392],
#        [121873]])

# %%
##train the AI using sklearn library to import linearregression
from sklearn.linear_model import LinearRegression

##store linearRegression model into a variable model
model = LinearRegression()

# %%
##use the fit funtion to train the AI by passing input and output data

model.fit(xProcessed, yProcessed)
# Out:
# LinearRegression()

# %%
##use the predit funtion to check AI

model.predict([[12]])
# Out:
# array([[138247.75182398]])

# %%
##use the score funtion to measure performance
##Because we have perfectly linear data set we 1.0 perfect score
model.score(xProcessed,yProcessed)
# Out:
# 0.9569566641435086
